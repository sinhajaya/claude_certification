# %%
import boto3

client = boto3.client("bedrock-runtime", region_name="ap-south-1")
model_id = "apac.anthropic.claude-3-5-sonnet-20240620-v1:0"

def add_user_message(messages,text):
    user_message = {
        "role": "user",
        "content": [
            {"text":text}
        ]
    }
    messages.append(user_message)

def add_assistant_message(messages,text):
    assistant_message = {
        "role": "assistant",
        "content": [
            {"text":text}
        ]
    }
    messages.append(assistant_message)

def chat(messages,system=None,temperature=1.0):
    params = {
        "modelId": model_id,
        "messages": messages,
        "inferenceConfig": {"temperature": temperature}
    }

    if system:
        params["system"] = [{"text":system}]

    response = client.converse(**params)

    return response["output"]["message"]["content"][0]["text"]

# %%
messages = []

add_user_message(messages, "Generate a movie idea in one sentence.")
text = chat(messages,temperature=0.0)

print(text)

# %%
messages = []

add_user_message(messages,"How do I host Postgres database?")
text = chat(messages,system="""
    You are an AWS cloud support specialist. Your job is to answer user queries related to
    cloud hosting services on AWS.
    """)

print(text)

# %%
messages = []

add_user_message(messages, "Write a function that checks a string for duplicate characters.")
text = chat(messages, system="You are a python engineer who writes a very concise code.")

print(text)
